# %% [markdown]
# # SQL Agent Demo
#
# Generate, review and execute a PostgreSQL query with one function.

# %%
from sql_agent import ask_sql

# %%
result = ask_sql(
    "Show daily revenue by platform for non-test users."
)

# %%
print(result.final_sql)
display(result.data)
