# %% [markdown]
# # SQL Agent Demo
#
# This notebook will demonstrate the SQL writer, SQL reviewer and database execution workflow.

# %% [markdown]
# The working implementation will be added after the synthetic CSV data is defined.
